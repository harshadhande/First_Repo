# %% [markdown]
# <a href="https://colab.research.google.com/github/harshadhande/First_Repo/blob/main/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Creating Series Objects from list

# %%
#string
country=['India','Pakistan','Bangladesh','Nepal','Bhutan']

pd.Series(country)
# Out:
# 0         India
# 1      Pakistan
# 2    Bangladesh
# 3         Nepal
# 4        Bhutan
# dtype: object

# %%
abc=[13,65,34,98,70,34]
pqr=pd.Series(abc)
print(pqr)
# Out:
# 0    13
# 1    65
# 2    34
# 3    98
# 4    70
# 5    34
# dtype: int64

# %%
#custom index
marks=[95,87,85,94,47]
sub=['DA','DMS','PT&RP','BHR','UHV']
pd.Series(marks,index=sub)
# Out:
# DA       95
# DMS      87
# PT&RP    85
# BHR      94
# UHV      47
# dtype: int64

# %%
#setting a name
pd.Series(marks,index=sub,name='marks of Harsha')
# Out:
# DA       95
# DMS      87
# PT&RP    85
# BHR      94
# UHV      47
# Name: marks of Harsha, dtype: int64

# %% [markdown]
# #Creating Series Object from Dictionary

# %%
marks1={'DA':95,'DMS':87,'PT&RP':85,'BHR':94,'UHV':47}
abc=pd.Series(marks1,name='marks of Harsha')
abc
# Out:
# DA       95
# DMS      87
# PT&RP    85
# BHR      94
# UHV      47
# Name: marks of Harsha, dtype: int64

# %%
marks1={'DA':95,'DMS':87,'PT&RP':85,'BHR':np.nan,'UHV':47}
xyz=pd.Series(marks1,name='marks of Harsha')
xyz
# Out:
# DA       95.0
# DMS      87.0
# PT&RP    85.0
# BHR       NaN
# UHV      47.0
# Name: marks of Harsha, dtype: float64

# %% [markdown]
# #Series Attributes

# %%
abc
# Out:
# DA       95
# DMS      87
# PT&RP    85
# BHR      94
# UHV      47
# Name: marks of Harsha, dtype: int64

# %%
#Index
abc.index
# Out:
# Index(['DA', 'DMS', 'PT&RP', 'BHR', 'UHV'], dtype='object')

# %%
#values
abc.values
# Out:
# array([95, 87, 85, 94, 47])

# %%
#Dtype
abc.dtype
# Out:
# dtype('int64')

# %%
#Shape
abc.shape
# Out:
# (5,)

# %%
#Size
abc.size
# Out:
# 5

# %%
#is_unique
abc.is_unique

check_unique=pd.Series([1,2,3,1,5,3])
check_unique.is_unique
# Out:
# False

# %%
#common functions and attributes in pandas
check_unique.cumsum()
check_unique.cumprod()
check_unique.median()
#check_unique.mean()
# Out:
# 2.5

# %%
#Reading a csv

movies=pd.read_csv(r'/content/bollywood.csv',index_col='movie')
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies.head()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
movies.tail()
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
movies.head(10)
# Out:
#                                                       lead
# movie
# Uri: The Surgical Strike                     Vicky Kaushal
# Battalion 609                                  Vicky Ahuja
# The Accidental Prime Minister (film)           Anupam Kher
# Why Cheat India                              Emraan Hashmi
# Evening Shadows                           Mona Ambegaonkar
# Soni (film)                           Geetika Vidya Ohlyan
# Fraud Saiyaan                                 Arshad Warsi
# Bombairiya                                    Radhika Apte
# Manikarnika: The Queen of Jhansi            Kangana Ranaut
# Thackeray (film)                       Nawazuddin Siddiqui

# %%
movies.tail(10)
# Out:
#                                         lead
# movie
# Raaz (2002 film)                  Dino Morea
# Zameen (2003 film)                Ajay Devgn
# Waisa Bhi Hota Hai Part II      Arshad Warsi
# Devdas (2002 Hindi film)      Shah Rukh Khan
# Kaante                      Amitabh Bachchan
# Hum Tumhare Hain Sanam        Shah Rukh Khan
# Aankhen (2002 film)         Amitabh Bachchan
# Saathiya (film)                 Vivek Oberoi
# Company (film)                    Ajay Devgn
# Awara Paagal Deewana            Akshay Kumar

# %%
movies.sample() #get only one row
# Out:
#                                lead
# movie
# The Journey of Karma  Shakti Kapoor

# %%
movies.sample(5)
# Out:
#                                  lead
# movie
# Shabnam Mausi           Ashutosh Rana
# Hum Hai Raahi Car Ke      Anupam Kher
# Guest iin London        Kartik Aaryan
# Elaan (2005 film)        Arjun Rampal
# Gulabi Gang (film)    Sampat Pal Devi

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
import pandas as pd
virat_kohli=pd.read_csv(r'/content/kohli_ipl.csv',index_col='match_no')
virat_kohli
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
virat_kohli.value_counts()
# Out:
# runs
# 0       9
# 1       8
# 12      8
# 9       7
# 8       6
#        ..
# 92      1
# 99      1
# 108     1
# 109     1
# 113     1
# Name: count, Length: 78, dtype: int64

# %%
virat_kohli.sort_values(ascending=False,by='runs')
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 120        100
# 164        100
# ...        ...
# 93           0
# 130          0
# 206          0
# 207          0
# 211          0
#
# [215 rows x 1 columns]

# %%
#high score od virat
virat_kohli.sort_values(ascending=False,by='runs').head(1).values[0]
# Out:
# array([113])

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
#sort_index -> inplace -> movies
movies.sort_index(ascending=False,inplace=True)
movies
# Out:
#                                         lead
# movie
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
# Zokkomon                     Darsheel Safary
# Zindagi Tere Naam         Mithun Chakraborty
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi 50-50                    Veena Malik
# ...                                      ...
# 2 States (2014 film)            Arjun Kapoor
# 1971 (2007 film)              Manoj Bajpayee
# 1920: The Evil Returns           Vicky Ahuja
# 1920: London                   Sharman Joshi
# 1920 (film)                 Rajniesh Duggall
#
# [1500 rows x 1 columns]

# %%
virat_kohli.sort_values(inplace=True, by='runs')
virat_kohli
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %% [markdown]
# #Series Maths Methods

# %%
virat_kohli.count()
# Out:
# runs    215
# dtype: int64

# %%
virat_kohli.sum()
# Out:
# runs    6634
# dtype: int64

# %%
mean=virat_kohli.mean()
median=virat_kohli.median()
mode=virat_kohli.mode()
std=virat_kohli.std()
var=virat_kohli.var()
print('mean' ,mean,'\nmedian', median,'\nmode', mode,'\nstd', std,'\nvar', var)
# Out:
# mean runs    30.855814
# dtype: float64
# median runs    24.0
# dtype: float64
# mode    runs
# 0     0
# std runs    26.229801
# dtype: float64
# var runs    688.002478
# dtype: float64

# %%
virat_kohli.max()
# Out:
# runs    113
# dtype: int64

# %%
virat_kohli.min()
# Out:
# runs    0
# dtype: int64

# %%
virat_kohli.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %% [markdown]
# #Series Indexing

# %%
a=pd.Series([1,4,3,5,6,87,45,23,12,52,34,12])
a
# Out:
# 0      1
# 1      4
# 2      3
# 3      5
# 4      6
# 5     87
# 6     45
# 7     23
# 8     12
# 9     52
# 10    34
# 11    12
# dtype: int64

# %%
a[5]
# Out:
# np.int64(87)

# %%
a[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-a01440cf14bb> in <cell line: 0>()
# ----> 1 a[-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
abc[-1]
# Out:
# <ipython-input-80-295284f300e9>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   abc[-1]
# np.int64(47)

# %%
# Slicing
virat_kohli[5:15]
# Out:
#           runs
# match_no
# 207          0
# 135          0
# 130          0
# 211          0
# 106          1
# 204          1
# 113          1
# 77           1
# 1            1
# 5            1

# %%
movies[::2]
# Out:
#                                      lead
# movie
# Zor Lagaa Ke...Haiya!       Meghan Jadhav
# Zindagi Tere Naam      Mithun Chakraborty
# Zindagi 50-50                 Veena Malik
# Zinda (film)                  Sanjay Dutt
# Zid (2014 film)            Mannara Chopra
# ...                                   ...
# 3 Storeys                     Aisha Ahmed
# 3 Deewarein              Naseeruddin Shah
# 22 Yards                      Barun Sobti
# 1971 (2007 film)           Manoj Bajpayee
# 1920: London                Sharman Joshi
#
# [750 rows x 1 columns]

# %% [markdown]
# #Editing Series

# %%
abc
# Out:
# DA       95
# DMS      87
# PT&RP    85
# BHR      94
# UHV      47
# Name: marks of Harsha, dtype: int64

# %%
abc[1]=100
abc
# Out:
# <ipython-input-49-c85765acfade>:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   abc[1]=100
# DA        95
# DMS      100
# PT&RP     85
# BHR       94
# UHV       47
# Name: marks of Harsha, dtype: int64

# %%
#what if an index is not exist
abc['AI']=99
abc
# Out:
# DA        95
# DMS      100
# PT&RP     85
# BHR       94
# UHV       47
# AI        99
# Name: marks of Harsha, dtype: int64

# %%
pqr
# Out:
# 0    13
# 1    65
# 2    34
# 3    98
# 4    70
# 5    34
# dtype: int64

# %%
pqr[1:4]=98
pqr
# Out:
# 0    13
# 1    98
# 2    98
# 3    98
# 4    70
# 5    34
# dtype: int64

# %%
# fancy indexing
pqr[[0,2,4]] = [0,0,0]
pqr
# Out:
# 0     0
# 1    98
# 2     0
# 3    98
# 4     0
# 5    34
# dtype: int64

# %% [markdown]
# #Python Functions On Series

# %%
print(len(pqr))
print(type(pqr))
print(dir(pqr))
print(sorted(pqr))
print(min(pqr))
print(max(pqr))
# Out:
# 6
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
list(abc)
# Out:
# [95, 100, 85, 94, 47, 99]

# %%
dict(pqr)
# Out:
# {0: np.int64(0),
#  1: np.int64(98),
#  2: np.int64(0),
#  3: np.int64(98),
#  4: np.int64(0),
#  5: np.int64(34)}

# %%
#membership operator
'Zinda' in movies
# Out:
# False

# %%
'Sanjay Dutt' in movies.values
# Out:
# True

# %%
virat_kohli >= 50
# Out:
#            runs
# match_no
# 8         False
# 87        False
# 93        False
# 91        False
# 206       False
# ...         ...
# 164        True
# 120        True
# 123        True
# 126        True
# 128        True
#
# [215 rows x 1 columns]

# %%
virat_kohli[virat_kohli >= 50]
(virat_kohli >= 50).sum()
# Out:
# runs    50
# dtype: int64

# %%
(virat_kohli ==0).sum()
# Out:
# runs    9
# dtype: int64

# %% [markdown]
# #Questions Based on Real World example

# %%
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
#astype
import sys
sys.getsizeof(virat_kohli)
# Out:
# 3472

# %%
#astype
import sys
sys.getsizeof(virat_kohli.astype('int32'))
# Out:
# 2612

# %% [markdown]
# #Plotting Histogram using Pandas

# %%
virat_kohli.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#clip
t=pd.Series([1,1,2,2,3,3,3,6,4,5,7,4,9,7,4,6,2,4])
t.clip(2,6)
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     3
# 5     3
# 6     3
# 7     6
# 8     4
# 9     5
# 10    6
# 11    4
# 12    6
# 13    6
# 14    4
# 15    6
# 16    2
# 17    4
# dtype: int64

# %%
t
# Out:
# 0     1
# 1     1
# 2     2
# 3     2
# 4     3
# 5     3
# 6     3
# 7     6
# 8     4
# 9     5
# 10    7
# 11    4
# 12    9
# 13    7
# 14    4
# 15    6
# 16    2
# 17    4
# dtype: int64

# %%
#drop_duplicates
t.drop_duplicates()
# Out:
# 0     1
# 2     2
# 4     3
# 7     6
# 8     4
# 9     5
# 10    7
# 12    9
# dtype: int64

# %%
t.drop_duplicates(keep='first')
# Out:
# 0     1
# 2     2
# 4     3
# 7     6
# 8     4
# 9     5
# 10    7
# 12    9
# dtype: int64

# %%
t.drop_duplicates(keep='last')
# Out:
# 1     1
# 6     3
# 9     5
# 12    9
# 13    7
# 15    6
# 16    2
# 17    4
# dtype: int64

# %%
t.drop_duplicates().sum()
# Out:
# np.int64(37)

# %%
import pandas as pd
import numpy as np

# %%
t = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
t
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
#dropna
t.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
#set type is unordered
#pf={1,2,3,4,5}
#d.Series(pf)

# %% [markdown]
# #Creating DataFrame

# %%
#using list
stu_data=[
    [23,54,23],
    [45,23,23],
    [34,34,12],
     [23,87,34]
]
pd.DataFrame(stu_data,columns=['iq','marks','packages'])
# Out:
#    iq  marks  packages
# 0  23     54        23
# 1  45     23        23
# 2  34     34        12
# 3  23     87        34

# %%
import pandas as pd
#using read csv
movies=pd.read_csv(r'/content/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# #Dataframe Attributes

# %%
#dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %% [markdown]
# #Dataframe Methods

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %%
movies.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
movies.sample()#random only one
# Out:
#         title_x    imdb_id                                        poster_path  \
# 148  5 Weddings  tt1971310  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                     wiki_link     title_y original_title  \
# 148  https://en.wikipedia.org/wiki/5_Weddings  5 Weddings     5 Weddings
#
#      is_adult  year_of_release runtime                genres  imdb_rating  \
# 148         0             2018      90  Comedy|Drama|Romance          3.2
#
#      imdb_votes                                              story  \
# 148         316  An American journalist travels to India for wh...
#
#                                                summary  \
# 148  An American journalist travels to India to cov...
#
#                                    tagline  \
# 148  The Only Journey Is The One Within...
#
#                                                 actors wins_nominations  \
# 148  Nargis Fakhri|Rajkummar Rao|Bo Derek|Candy Cla...              NaN
#
# ...

# %%
movies.sample(4)#random
# Out:
#                             title_x    imdb_id  \
# 767             Shagird (2011 film)  tt1828289
# 399               Mr. X (2015 film)  tt3848938
# 1393      Thoda Tum Badlo Thoda Hum  tt0420250
# 1059  The Blue Umbrella (2005 film)  tt0457802
#
#                                             poster_path  \
# 767   https://upload.wikimedia.org/wikipedia/en/thum...
# 399   https://upload.wikimedia.org/wikipedia/en/thum...
# 1393  https://upload.wikimedia.org/wikipedia/en/thum...
# 1059  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 767   https://en.wikipedia.org/wiki/Shagird_(2011_film)
# 399     https://en.wikipedia.org/wiki/Mr._X_(2015_film)
# 1393  https://en.wikipedia.org/wiki/Thoda_Tum_Badlo_...
# 1059  https://en.wikipedia.org/wiki/The_Blue_Umbrell...
#
#                         title_y             original_title  is_adult  \
# 767                     Shagird                    Shagird         0
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
movies.isnull().sum().sum()
#sum of all null values
# Out:
# np.int64(2229)

# %%
#duplicated
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
 students = pd.DataFrame(stu_data,columns=['iq','marks','packages'])
 students
# Out:
#    iq  marks  packages
# 0  23     54        23
# 1  45     23        23
# 2  34     34        12
# 3  23     87        34

# %%
students.duplicated().sum()
# Out:
# np.int64(0)

# %%
students.rename(columns={'marks':'percent','packages':'LPA'},inplace=True)
students
# Out:
#    iq  percent  LPA
# 0  23       54   23
# 1  45       23   23
# 2  34       34   12
# 3  23       87   34

# %% [markdown]
# #Maths Methods

# %%
#sum >- axis argument
students.sum(axis=0)
# Out:
# iq         125
# percent    198
# LPA         92
# dtype: int64

# %%
students.mean(axis=1)
# Out:
# 0    33.333333
# 1    30.333333
# 2    26.666667
# 3    48.000000
# dtype: float64

# %%
students.var()
# Out:
# iq         110.916667
# percent    789.666667
# LPA         80.666667
# dtype: float64

# %% [markdown]
# #Selecting Columns from dataframe

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
 #single cols
movies['title_x'] #Prone to Error
# movies.columns
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
# multiple cols
movies[['year_of_release','actors','title_x']]
# Out:
#       year_of_release                                             actors  \
# 0                2019  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1                2019  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2                2019  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3                2019  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4                2018  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...               ...                                                ...
# 1624             2001  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625             2001  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626             2018  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627             2019                          Gippy Grewal|Zareen Khan|
# 1628             2011                                        Fawad Khan|
#
#                                    title_x
# 0                 Uri: The Surgical Strike
# ...

# %% [markdown]
# #Loc and iloc

# %%
#single row
movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
# multiple row
movies.iloc[:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# movies.loc['Evening Shadows'] # Show error
movies.loc[4]
# Out:
# title_x                                               Evening Shadows
# imdb_id                                                     tt6028796
# poster_path                                                       NaN
# wiki_link               https://en.wikipedia.org/wiki/Evening_Shadows
# title_y                                               Evening Shadows
# original_title                                        Evening Shadows
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                           102
# genres                                                          Drama
# imdb_rating                                                       7.3
# imdb_votes                                                        280
# story               While gay rights and marriage equality has bee...
# ...

# %% [markdown]
# #Selecting Both rows and Column

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
